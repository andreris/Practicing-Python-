# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
datos = np.array([10, 20, 30, 40, 50])

# Calcular el promedio
promedio = np.mean(datos)

print("El promedio es:", promedio)

x = 1 
a = 2
B = a + x
print(B)
# Out:
# El promedio es: 30.0
# 3

# %% [markdown]
# Elements of Python
#
# Vocabulary / Words – Variables and Reserved words (Chapter 2)
# Sentence structure – valid syntax patterns (Chapters 3–5)
# Story structure – constructing a program for a purpose

# %% [markdown]
# python is sequential

# %%
a = True
b = False
b = 3
print(b)
# Out:
# 3

# %%
x =3
print(x)
x = x +6
print (x)
# Out:
# 3
# 9

# %%
x = 20
if x > 5:
    print("x es mayor que 5")
if x < 5:
    print("x es menor que 5")
print("Fin del programa")
# Out:
# x es mayor que 5
# Fin del programa

# %%
n = 15
while n > 0:
    print(n)
    n = n - 1
print("Fin del bucle")

# %% [markdown]
# mnemonic: variable that helps you to remind
# patterns: sequential, conditional, repeated, store & compute
# sentences or lines: variable, constant, function, operator
# numeric expressions: x-multiply, ** - power, % - remainder
# order of operation: it goes from the left to the right
# priority order: parenthesis, power, multiplication
#
# variables, constants and literals have type
# string, integer
# the text goes with '' like: 'andre'
# python stops when a code line gives an error
# type conversion: when you put float, you ar forcing the
# string conversion: if you have text '123', with int you can convert it
# input() returns a string
# indentation: in python the blocks are defined by  indentation, not by symbols
# types of number : integers, floating point numbers(decimal)
# types of variables:
