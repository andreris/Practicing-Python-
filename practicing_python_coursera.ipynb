# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
datos = np.array([10, 20, 30, 40, 50])

# Calcular el promedio
promedio = np.mean(datos)

print("El promedio es:", promedio)

x = 1 
a = 2
B = a + x
print(B)
# Out:
# El promedio es: 30.0
# 3

# %% [markdown]
# Elements of Python
#
# Vocabulary / Words – Variables and Reserved words (Chapter 2)
# Sentence structure – valid syntax patterns (Chapters 3–5)
# Story structure – constructing a program for a purpose

# %% [markdown]
# python is sequential

# %%
a = True
b = False
b = 3
print(b)
# Out:
# 3

# %%
x =3
print(x)
x = x +6
print (x)
# Out:
# 3
# 9

# %%
x = 20
if x > 5:
    print("x es mayor que 5")
if x < 5:
    print("x es menor que 5")
print("Fin del programa")
# Out:
# x es mayor que 5
# Fin del programa

# %%
n = 15
while n > 0:
    print(n)
    n = n - 1
print("Fin del bucle")

# %% [markdown]
# #### Mnemonic
# Variable that helps you remember what it stores.
#
# #### Patterns
# - Sequential
# - Conditional
# - Repeated
# - Store & Compute
#
# #### Sentences or Lines
# - Variable
# - Constant
# - Function
# - Operator
#
# #### Numeric Expressions
# - *  → multiply
# - ** → power
# - %  → remainder
#
# #### Order of Operations
# It goes from left to right when operators have the same priority.
#
# #### Priority Order
# 1. Parenthesis ()
# 2. Power **
# 3. Multiplication *, Division /, Modulo %
# 4. Addition +, Subtraction -
#
# #### Variables, Constants and Literals
# They have types.
#
# #### Types
# - String
# - Integer
# - Float
#
# #### Strings
# Text goes inside quotes:
# 'andre'
#
# #### Errors
# Python stops when a line of code gives an error.
#
# #### Type Conversion
# When you use float(), you are forcing conversion to decimal.
#
# #### String to Integer Conversion
# If you have text like '123', you can convert it using int().
#
# #### input()
# input() always returns a string.
#
# #### Indentation
# In Python, blocks are defined by indentation, not by symbols.
#
# #### Types of Numbers
# - Integers
# - Floating point numbers (decimals)
#
# #### Types of Variables
# - Numeric
# - String
# - Boolean
#
# ##### code
# git add .
# git commit -m "Actualización del proyecto"
# git push
